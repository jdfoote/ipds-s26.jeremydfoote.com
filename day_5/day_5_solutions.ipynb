# %% [markdown]
# ## PY4E Ch 9

# %% [markdown]
# Exercise 2: Write a program that categorizes each mail message by which day of the week the commit was done. To do this look for lines that start with “From”, then look for the third word and keep a running count of each of the days of the week. At the end of the program print out the contents of your dictionary (order does not matter).
#
# Sample Line:
#
# ```
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# ```
#
# Sample Execution:
#
# ```python
#     python dow.py
#     Enter a file name: mbox-short.txt
#     {'Fri': 20, 'Thu': 6, 'Sat': 1}
# ```

# %% [markdown]
# Exercise 3: Write a program to read through a mail log, build a histogram using a dictionary to count how many messages have come from each email address, and print the dictionary.
#
#     Enter file name: mbox-short.txt
#     {'gopal.ramasammycook@gmail.com': 1, 'louis@media.berkeley.edu': 3,
#     'cwen@iupui.edu': 5, 'antranig@caret.cam.ac.uk': 1,
#     'rjlowe@iupui.edu': 2, 'gsilver@umich.edu': 3,
#     'david.horwitz@uct.ac.za': 4, 'wagnermr@iupui.edu': 1,
#     'zqian@umich.edu': 4, 'stephen.marquard@uct.ac.za': 2,
#     'ray@media.berkeley.edu': 1}

# %% [markdown]
# Exercise 4: Add code to the above program to figure out who has the most messages in the file. After all the data has been read and the dictionary has been created, look through the dictionary using a maximum loop (see Chapter 5: Maximum and minimum loops) to find who has the most messages and print how many messages the person has.
#
#     Enter a file name: mbox-short.txt
#     cwen@iupui.edu 5
#
#     Enter a file name: mbox.txt
#     zqian@umich.edu 195

# %%
email_count = {}
with open('./mbox-short.txt', 'r') as f:
    for line in f:
        if line[:5] == "From ":
            line_list = line.split()
            email = line_list[1]
            if email not in email_count:
                email_count[email] = 1
            else:
                email_count[email] = email_count[email] + 1


max_count = 0
max_email = None

for email in email_count:
    curr_count = email_count[email]
    if curr_count > max_count:
        max_count = curr_count
        max_email = email

print(f"The most prolific emailer was {max_email}, who sent {max_count} emails")
# Out:
# The most prolific emailer was cwen@iupui.edu, who sent 5 emails

# %% [markdown]
# ## 9.5
#
# This program records the domain name (instead of the address) where the message was sent from instead of who the mail came from (i.e., the whole email address). At the end of the program, print out the contents of your dictionary.

# %% [markdown]
# ## PY4E Ch 10

# %% [markdown]
# Exercise 1: Revise a previous program as follows: Read and parse the “From” lines and pull out the addresses from the line. Count the number of messages from each person using a dictionary.
#
# After all the data has been read, print the person with the most commits by creating a list of (count, email) tuples from the dictionary. Then sort the list in reverse order and print out the person who has the most commits.
#
#     Sample Line:
#     From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
#     Enter a file name: mbox-short.txt
#     cwen@iupui.edu 5
#
#     Enter a file name: mbox.txt
#     zqian@umich.edu 195

# %%
email_count = {}
with open('./mbox-short.txt', 'r') as f:
    for line in f:
        if line[:5] == "From ":
            line_list = line.split()
            email = line_list[1]
            if email not in email_count:
                email_count[email] = 1
            else:
                email_count[email] = email_count[email] + 1
        else:
            continue

emails_list = []
for email, count in email_count.items():
    emails_list.append((count, email))

sorted(emails_list, reverse=True)
# Out:
# [(5, 'cwen@iupui.edu'),
#  (4, 'zqian@umich.edu'),
#  (4, 'david.horwitz@uct.ac.za'),
#  (3, 'louis@media.berkeley.edu'),
#  (3, 'gsilver@umich.edu'),
#  (2, 'stephen.marquard@uct.ac.za'),
#  (2, 'rjlowe@iupui.edu'),
#  (1, 'wagnermr@iupui.edu'),
#  (1, 'ray@media.berkeley.edu'),
#  (1, 'gopal.ramasammycook@gmail.com'),
#  (1, 'antranig@caret.cam.ac.uk')]

# %% [markdown]
# Exercise 2: This program counts the distribution of the hour of the day for each of the messages. You can pull the hour from the “From” line by finding the time string and then splitting that string into parts using the colon character. Once you have accumulated the counts for each hour, print out the counts, one per line, sorted by hour as shown below.
#
#     python timeofday.py
#     Enter a file name: mbox-short.txt
#     04 3
#     06 1
#     07 1
#     09 2
#     10 3
#     11 6
#     14 1
#     15 2
#     16 4
#     17 2
#     18 1
#     19 1

# %% [markdown]
# ### 10.3
#
# Exercise 3: Write a program that reads a file and prints the letters in decreasing order of frequency.
#
# Your program should convert all the input to lower case and only count the letters a-z. Your program should not count spaces, digits, punctuation, or anything other than the letters a-z. Find text samples from several different languages and see how letter frequency varies between languages. Compare your results with the tables at https://wikipedia.org/wiki/Letter_frequencies.

# %%
good_letters = 'abcdefghijklmnopqrstuvwxyz'
#good_letters = 'aeiou'
letter_counts = {}
with open('mbox-short.txt', 'r') as f:
    for line in f:
        for letter in line.lower():
            if letter not in good_letters:
               # if letter not in letter_counts:
               #     letter_counts[letter] = 1
               # else:
               #     letter_counts[letter] += 1
               letter_counts[letter] = letter_counts.get(letter, 0) + 1

count_tuples = []
for letter, count in letter_counts.items():
    count_tuples.append((count, letter))
sorted(count_tuples, reverse=True)
# Out:
# [(7726, ' '),
#  (3856, '.'),
#  (3466, '0'),
#  (3053, '-'),
#  (1923, '1'),
#  (1921, '/'),
#  (1910, '\n'),
#  (1750, ':'),
#  (1603, '2'),
#  (1044, '4'),
#  (986, '8'),
#  (852, '3'),
#  (728, '5'),
#  (609, ')'),
#  (609, '('),
#  (559, '7'),
#  (514, '9'),
#  (470, '6'),
#  (436, '\t'),
#  (336, '@'),
#  (324, ';'),
#  (282, ','),
#  (243, ']'),
#  (243, '['),
#  (166, '>'),
#  (135, '='),
#  (135, '<'),
#  (84, '+'),
#  (56, '_'),
#  (27, '?'),
#  (27, '&'),
#  (21, '|'),
#  (8, '"'),
#  (6, "'"),
#  (4, '~'),
#  (1, '#')]

# %% [markdown]
# ## Jeremy's Notebook Exercises
#
# 1. See if you can modify the code above to count how often each word appears instead.

# %%
string = """
I have been one acquainted with the night.
I have walked out in rain—and back in rain.
I have outwalked the furthest city light.

I have looked down the saddest city lane.
I have passed by the watchman on his beat
And dropped my eyes, unwilling to explain.

I have stood still and stopped the sound of feet
When far away an interrupted cry
Came over houses from another street,

But not to call me back or say good-bye;
And further still at an unearthly height,
One luminary clock against the sky

Proclaimed the time was neither wrong nor right. 
I have been one acquainted with the night.
"""

string = string.lower()
string = string.replace('—', ' ')
string = string.replace(',', '')

# %% [markdown]
# 2. Reuse and modify the code above so that it prints a dictionary of the total population of cities that start with each letter of the alphabet.

# %% [markdown]
# ## Babynames
#
#
# Search for your own name. Are there both boys and girls that have your name? Is it more popular for one group than for the other?

# %%
NAMES_LIST = "baby_names/yob2022.txt"

# Creates two empty dictionaries - one for boys and one for girls
boys = {}
girls = {}

for line in open(NAMES_LIST, 'r').readlines():
    name, sex, count = line.strip().split(",")
    count = int(count)
    # Puts data about females in one dictionary and about males in the other
    if sex == "F":
        girls[name.lower()] = count
    elif sex == "M":
        boys[name.lower()] = count

# %% [markdown]
# Are there more boys' names or girls' names? What about for particular first letters? What about for ''every'' first letter?

# %% [markdown]
# What is the longest name in the dataset?

# %% [markdown]
# What is the most common name and how often does it occur?

# %% [markdown]
# What is the least common name and how often does it occur? Does that concern you?

# %% [markdown]
# How many boys and girls are described in the dataset (i.e., how many boys and girls born in 2018 have names given to at least four others)?

# %% [markdown]
# How many boys' names are also girls' names? How many girls' names are also boys' names?

# %% [markdown]
# How many names are subsets of other names?

# %%
all_names = list(boys.keys()) + list(girls.keys())

word_lengths = []

for name in all_names:
    name_len = len(name)
    word_lengths.append((name_len, name))

word_lengths = sorted(word_lengths)

subset_names = {}
index = 0

for count1, name1 in word_lengths:
    superset_names = []
    index = index + 1
    for count2, name2 in word_lengths[index:]:
        if count1 == count2:
            continue
        elif name1 in name2:
            superset_names.append(name2)
        else:
            continue
    if len(superset_names) > 0:
        subset_names[name1] = superset_names

for k,v in subset_names.items():
    print(f"There are {len(v)} names that contain the name {k}")
# Out:
# There are 153 names that contain the name aj
# There are 2487 names that contain the name al
# There are 5184 names that contain the name an
# There are 103 names that contain the name bo
# There are 2 names that contain the name cj
# There are 106 names that contain the name cy
# There are 12 names that contain the name dj
# There are 148 names that contain the name eh
# There are 44 names that contain the name ej
# There are 107 names that contain the name fe
# There are 597 names that contain the name io
# There are 1342 names that contain the name ja
# There are 1 names that contain the name jc
# There are 4 names that contain the name jd
# There are 1 names that contain the name jj
# There are 446 names that contain the name jo
# There are 11 names that contain the name jr
# There are 1 names that contain the name jt
# There are 5 names that contain the name jw
# There are 510 names that contain the name ki
# There are 351 names that contain the name ky
# There are 2697 names that contain the name la
# There are 5 names that contain the name lj
# There are 755 names that contain the name lo
# There are 315 names that contain the name lu
# There are 18 names that contain the name md
# There are 4 names that contain the name mj
# There are 152 names that contain the name mu
# There are 271 names that contain the name my
# There are 288 names that contain the name om
# There are 1061 names that contain the name or
# There are 69 names that contain the name oz
# There are 2323 names that contain the name ra
# There are 16 names that contain the name rj
# There are 845 names that contain the name ro
# There are 281 names that contain the name ru
# There are 696 names that contain the name ry
# There are 1 names that contain the name sj
# There are 191 names that contain the name su
# There are 256 names that contain the name sy
# There are 3 names that contain the name tj
# There are 318 names that contain the name ty
# There are 906 names that contain the name vi
# There are 133 names that contain the name vy
# There are 99 names that contain the name xi
# There are 307 names that contain the name ye
# There are 151 names that contain the name yi
# There are 146 names that contain the name yu
# There are 125 names that contain the name zo
# There are 156 names that contain the name zy
# There are 151 names that contain the name abe
# There are 67 names that contain the name abi
# There are 5 names that contain the name abu
# There are 8 names that contain the name aby
# There are 128 names that contain the name ace
# There are 166 names that contain the name ada
# There are 189 names that contain the name ade
# There are 183 names that contain the name adi
# There are 113 names that contain the name aia
# There are 44 names that contain the name aja
# There are 96 names that contain the name aki
# There are 377 names that contain the name ala
# There are 586 names that contain the name ali
# There are 87 names that contain the name alo
# There are 11 names that contain the name alp
# There are 261 names that contain the name aly
# There are 452 names that contain the name ama
# There are 370 names that contain the name ami
# There are 46 names that contain the name amr
# There are 77 names that contain the name amy
# There are 738 names that contain the name ana
# There are 9 names that contain the name anh
# There are 773 names that contain the name ani
# There are 720 names that contain the name ann
# There are 43 names that contain the name anu
# There are 191 names that contain the name any
# There are 6 names that contain the name aoi
# There are 363 names that contain the name ara
# There are 996 names that contain the name ari
# There are 59 names that contain the name ark
# There are 95 names that contain the name aro
# There are 103 names that contain the name art
# There are 174 names that contain the name ary
# There are 70 names that contain the name asa
# There are 77 names that contain the name ase
# There are 253 names that contain the name ash
# There are 108 names that contain the name ata
# There are 2 names that contain the name aum
# There are 158 names that contain the name ava
# There are 169 names that contain the name ave
# There are 296 names that contain the name avi
# There are 51 names that contain the name avy
# There are 32 names that contain the name awa
# There are 13 names that contain the name aws
# There are 15 names that contain the name axe
# There are 8 names that contain the name axl
# There are 406 names that contain the name aya
# There are 45 names that contain the name ayo
# There are 162 names that contain the name aza
# There are 114 names that contain the name azi
# There are 2 names that contain the name bam
# There are 26 names that contain the name bay
# There are 22 names that contain the name bea
# There are 14 names that contain the name bee
# There are 6 names that contain the name bek
# There are 70 names that contain the name ben
# There are 8 names that contain the name bex
# There are 21 names that contain the name bia
# There are 3 names that contain the name blu
# There are 5 names that contain the name bob
# There are 1 names that contain the name boe
# There are 12 names that contain the name bow
# There are 5 names that contain the name boy
# There are 232 names that contain the name bri
# There are 9 names that contain the name bru
# There are 1 names that contain the name bud
# There are 63 names that contain the name cai
# There are 120 names that contain the name cal
# There are 80 names that contain the name cam
# There are 37 names that contain the name can
# There are 9 names that contain the name cap
# There are 66 names that contain the name cas
# There are 3 names that contain the name caz
# There are 124 names that contain the name che
# There are 90 names that contain the name chi
# There are 69 names that contain the name cia
# There are 7 names that contain the name coa
# There are 3 names that contain the name coe
# There are 1 names that contain the name coi
# There are 7 names that contain the name coy
# There are 10 names that contain the name cru
# There are 21 names that contain the name dak
# There are 191 names that contain the name dal
# There are 176 names that contain the name dan
# There are 13 names that contain the name dax
# There are 84 names that contain the name day
# There are 40 names that contain the name dea
# There are 57 names that contain the name dee
# There are 202 names that contain the name del
# There are 18 names that contain the name deo
# There are 53 names that contain the name dev
# There are 6 names that contain the name dex
# There are 17 names that contain the name dez
# There are 86 names that contain the name dia
# There are 15 names that contain the name dim
# There are 32 names that contain the name dio
# There are 7 names that contain the name doc
# There are 39 names that contain the name dom
# There are 126 names that contain the name don
# There are 5 names that contain the name dot
# There are 10 names that contain the name dov
# There are 98 names that contain the name dre
# There are 5 names that contain the name dru
# There are 7 names that contain the name dua
# There are 170 names that contain the name ean
# There are 46 names that contain the name eda
# There are 46 names that contain the name edi
# There are 28 names that contain the name edy
# There are 9 names that contain the name efe
# There are 10 names that contain the name ege
# There are 334 names that contain the name ela
# There are 538 names that contain the name eli
# There are 108 names that contain the name elo
# There are 322 names that contain the name ely
# There are 140 names that contain the name ema
# There are 172 names that contain the name emi
# There are 25 names that contain the name emy
# There are 267 names that contain the name ena
# There are 46 names that contain the name eno
# There are 125 names that contain the name eon
# There are 131 names that contain the name era
# There are 247 names that contain the name eri
# There are 55 names that contain the name ero
# There are 33 names that contain the name esa
# There are 15 names that contain the name eto
# There are 128 names that contain the name eva
# There are 155 names that contain the name eve
# There are 79 names that contain the name evi
# There are 34 names that contain the name evy
# There are 9 names that contain the name ewa
# There are 34 names that contain the name eze
# There are 3 names that contain the name ezz
# There are 12 names that contain the name fae
# There are 12 names that contain the name fay
# There are 4 names that contain the name fey
# There are 14 names that contain the name fia
# There are 54 names that contain the name fin
# There are 1 names that contain the name fox
# There are 11 names that contain the name fyn
# There are 4 names that contain the name gad
# There are 31 names that contain the name gal
# There are 3 names that contain the name gea
# There are 6 names that contain the name gem
# There are 28 names that contain the name geo
# There are 52 names that contain the name gia
# There are 16 names that contain the name gil
# There are 34 names that contain the name gio
# There are 4 names that contain the name god
# There are 10 names that contain the name gor
# There are 22 names that contain the name gus
# There are 1 names that contain the name guy
# There are 148 names that contain the name hal
# There are 417 names that contain the name han
# There are 5 names that contain the name hoy
# There are 13 names that contain the name hud
# There are 7 names that contain the name hue
# There are 16 names that contain the name huk
# There are 12 names that contain the name hux
# There are 2 names that contain the name huy
# There are 419 names that contain the name iah
# There are 55 names that contain the name iam
# There are 741 names that contain the name ian
# There are 2 names that contain the name ibn
# There are 62 names that contain the name ice
# There are 103 names that contain the name ida
# There are 19 names that contain the name ido
# There are 44 names that contain the name idy
# There are 29 names that contain the name iga
# There are 41 names that contain the name ike
# There are 320 names that contain the name ila
# There are 68 names that contain the name ilo
# There are 188 names that contain the name ily
# There are 381 names that contain the name ina
# There are 259 names that contain the name ion
# There are 260 names that contain the name ira
# There are 153 names that contain the name ire
# There are 135 names that contain the name isa
# There are 104 names that contain the name ita
# There are 77 names that contain the name iva
# There are 87 names that contain the name ivi
# There are 19 names that contain the name ivo
# There are 23 names that contain the name ivy
# There are 618 names that contain the name iya
# There are 106 names that contain the name iza
# There are 79 names that contain the name jac
# There are 36 names that contain the name jad
# There are 39 names that contain the name jae
# There are 4 names that contain the name jag
# There are 121 names that contain the name jah
# There are 98 names that contain the name jai
# There are 62 names that contain the name jak
# There are 133 names that contain the name jan
# There are 37 names that contain the name jax
# There are 172 names that contain the name jay
# There are 1 names that contain the name jeb
# There are 9 names that contain the name jed
# There are 9 names that contain the name jem
# There are 2 names that contain the name jep
# There are 15 names that contain the name jet
# There are 15 names that contain the name jey
# There are 1 names that contain the name jhi
# There are 11 names that contain the name jia
# There are 12 names that contain the name jim
# There are 11 names that contain the name jin
# There are 9 names that contain the name jio
# There are 23 names that contain the name joa
# There are 3 names that contain the name job
# There are 11 names that contain the name joc
# There are 18 names that contain the name joe
# There are 3 names that contain the name joi
# There are 44 names that contain the name jon
# There are 12 names that contain the name joy
# There are 2 names that contain the name jru
# There are 24 names that contain the name jun
# There are 2 names that contain the name jyn
# There are 266 names that contain the name kai
# There are 4 names that contain the name kaj
# There are 152 names that contain the name kal
# There are 148 names that contain the name kam
# There are 7 names that contain the name kap
# There are 101 names that contain the name kas
# There are 209 names that contain the name kay
# There are 19 names that contain the name kaz
# There are 37 names that contain the name kea
# There are 75 names that contain the name kei
# There are 140 names that contain the name kel
# There are 223 names that contain the name ken
# There are 20 names that contain the name keo
# There are 37 names that contain the name khi
# There are 47 names that contain the name khy
# There are 62 names that contain the name kia
# There are 51 names that contain the name kie
# There are 42 names that contain the name kim
# There are 13 names that contain the name kio
# There are 8 names that contain the name kip
# There are 9 names that contain the name kit
# There are 13 names that contain the name koa
# There are 3 names that contain the name koe
# There are 3 names that contain the name koi
# There are 60 names that contain the name kol
# There are 2 names that contain the name koy
# There are 6 names that contain the name kru
# There are 28 names that contain the name kya
# There are 19 names that contain the name kye
# There are 13 names that contain the name kyi
# There are 5 names that contain the name kyo
# There are 75 names that contain the name lam
# There are 727 names that contain the name lan
# There are 16 names that contain the name law
# There are 155 names that contain the name lea
# There are 456 names that contain the name lee
# There are 373 names that contain the name len
# There are 73 names that contain the name leo
# There are 102 names that contain the name les
# There are 37 names that contain the name lev
# There are 9 names that contain the name lew
# There are 68 names that contain the name lex
# There are 511 names that contain the name lia
# There are 519 names that contain the name lin
# There are 90 names that contain the name lio
# There are 185 names that contain the name lis
# There are 59 names that contain the name liv
# There are 68 names that contain the name liz
# There are 10 names that contain the name loa
# There are 156 names that contain the name lon
# There are 46 names that contain the name lou
# There are 9 names that contain the name lua
# There are 65 names that contain the name luc
# There are 16 names that contain the name lui
# There are 31 names that contain the name lun
# There are 2 names that contain the name luv
# There are 13 names that contain the name lux
# There are 7 names that contain the name luz
# There are 86 names that contain the name lya
# There are 902 names that contain the name lyn
# There are 68 names that contain the name lys
# There are 74 names that contain the name mac
# There are 100 names that contain the name mae
# There are 123 names that contain the name mai
# There are 88 names that contain the name mak
# There are 210 names that contain the name mal
# There are 294 names that contain the name man
# There are 751 names that contain the name mar
# There are 28 names that contain the name mav
# There are 38 names that contain the name max
# There are 153 names that contain the name may
# There are 11 names that contain the name mea
# There are 8 names that contain the name meg
# There are 52 names that contain the name mei
# There are 178 names that contain the name mel
# There are 88 names that contain the name mia
# There are 7 names that contain the name mio
# There are 225 names that contain the name mir
# There are 5 names that contain the name mox
# There are 52 names that contain the name mya
# There are 105 names that contain the name nai
# There are 49 names that contain the name nam
# There are 99 names that contain the name nan
# There are 86 names that contain the name nas
# There are 34 names that contain the name naz
# There are 26 names that contain the name nea
# There are 19 names that contain the name ned
# There are 156 names that contain the name nel
# There are 4 names that contain the name neo
# There are 2 names that contain the name nhi
# There are 122 names that contain the name nia
# There are 31 names that contain the name nil
# There are 25 names that contain the name nio
# There are 15 names that contain the name niv
# There are 31 names that contain the name nix
# There are 27 names that contain the name noa
# There are 23 names that contain the name noe
# There are 114 names that contain the name nor
# There are 23 names that contain the name nox
# There are 2 names that contain the name noy
# There are 3 names that contain the name nuh
# There are 17 names that contain the name nur
# There are 77 names that contain the name nya
# There are 19 names that contain the name nyx
# There are 30 names that contain the name oak
# There are 39 names that contain the name obi
# There are 118 names that contain the name ola
# There are 88 names that contain the name ole
# There are 78 names that contain the name oli
# There are 88 names that contain the name omi
# There are 140 names that contain the name ona
# There are 209 names that contain the name oni
# There are 208 names that contain the name ora
# There are 223 names that contain the name ori
# There are 2 names that contain the name oso
# There are 87 names that contain the name ova
# There are 43 names that contain the name ovi
# There are 33 names that contain the name oya
# There are 16 names that contain the name pau
# There are 10 names that contain the name pax
# There are 2 names that contain the name phu
# There are 4 names that contain the name pia
# There are 2 names that contain the name pio
# There are 5 names that contain the name poe
# There are 65 names that contain the name que
# There are 51 names that contain the name rad
# There are 125 names that contain the name rae
# There are 205 names that contain the name rah
# There are 127 names that contain the name rai
# There are 29 names that contain the name raj
# There are 99 names that contain the name ram
# There are 260 names that contain the name ray
# There are 72 names that contain the name rea
# There are 62 names that contain the name red
# There are 70 names that contain the name rei
# There are 69 names that contain the name rem
# There are 252 names that contain the name ren
# There are 11 names that contain the name reo
# There are 39 names that contain the name rev
# There are 21 names that contain the name rex
# There are 147 names that contain the name rey
# There are 15 names that contain the name rez
# There are 456 names that contain the name ria
# There are 61 names that contain the name rik
# There are 36 names that contain the name rim
# There are 215 names that contain the name rin
# There are 121 names that contain the name rio
# There are 13 names that contain the name rip
# There are 32 names that contain the name riv
# There are 8 names that contain the name roa
# There are 25 names that contain the name rob
# There are 8 names that contain the name roe
# There are 11 names that contain the name roi
# There are 55 names that contain the name rom
# There are 133 names that contain the name ron
# There are 33 names that contain the name roo
# There are 33 names that contain the name roy
# There are 16 names that contain the name roz
# There are 5 names that contain the name rua
# There are 21 names that contain the name rue
# There are 7 names that contain the name rui
# There are 19 names that contain the name rut
# There are 109 names that contain the name rya
# There are 34 names that contain the name rye
# There are 123 names that contain the name ryn
# There are 13 names that contain the name ryo
# There are 6 names that contain the name ryu
# There are 85 names that contain the name sai
# There are 104 names that contain the name sal
# There are 134 names that contain the name sam
# There are 2 names that contain the name saw
# There are 19 names that contain the name sem
# There are 134 names that contain the name sen
# There are 21 names that contain the name set
# There are 144 names that contain the name shi
# There are 36 names that contain the name sho
# There are 29 names that contain the name shy
# There are 173 names that contain the name sia
# There are 32 names that contain the name sid
# There are 58 names that contain the name sir
# There are 10 names that contain the name ski
# There are 42 names that contain the name sky
# There are 56 names that contain the name sly
# There are 65 names that contain the name sol
# There are 21 names that contain the name sri
# There are 6 names that contain the name sua
# There are 6 names that contain the name sue
# There are 27 names that contain the name sun
# There are 22 names that contain the name sya
# There are 4 names that contain the name tad
# There are 44 names that contain the name tae
# There are 5 names that contain the name tag
# There are 52 names that contain the name tai
# There are 8 names that contain the name taj
# There are 152 names that contain the name tal
# There are 34 names that contain the name tam
# There are 1 names that contain the name tao
# There are 74 names that contain the name tay
# There are 9 names that contain the name taz
# There are 16 names that contain the name tea
# There are 8 names that contain the name ted
# There are 26 names that contain the name tee
# There are 2 names that contain the name tej
# There are 57 names that contain the name tel
# There are 17 names that contain the name teo
# There are 3 names that contain the name tex
# There are 63 names that contain the name tia
# There are 28 names that contain the name tim
# There are 19 names that contain the name tom
# There are 89 names that contain the name tor
# There are 82 names that contain the name tre
# There are 28 names that contain the name tru
# There are 31 names that contain the name tyr
# There are 6 names that contain the name udy
# There are 52 names that contain the name ula
# There are 45 names that contain the name uma
# There are 29 names that contain the name umi
# There are 67 names that contain the name una
# There are 133 names that contain the name uri
# There are 113 names that contain the name val
# There are 232 names that contain the name van
# There are 24 names that contain the name vea
# There are 16 names that contain the name ved
# There are 42 names that contain the name vee
# There are 149 names that contain the name via
# There are 21 names that contain the name vic
# There are 140 names that contain the name vin
# There are 31 names that contain the name vir
# There are 123 names that contain the name von
# There are 38 names that contain the name wes
# There are 61 names that contain the name wil
# There are 57 names that contain the name win
# There are 8 names that contain the name wit
# There are 51 names that contain the name wyn
# There are 15 names that contain the name xai
# There are 36 names that contain the name xan
# There are 18 names that contain the name xen
# There are 16 names that contain the name xia
# There are 2 names that contain the name xoe
# There are 4 names that contain the name xya
# There are 52 names that contain the name yaa
# There are 440 names that contain the name yan
# There are 1 names that contain the name yaw
# There are 19 names that contain the name yaz
# There are 23 names that contain the name yen
# There are 1 names that contain the name yue
# There are 2 names that contain the name yug
# There are 2 names that contain the name yui
# There are 20 names that contain the name yul
# There are 10 names that contain the name yuv
# There are 11 names that contain the name yva
# There are 24 names that contain the name zac
# There are 30 names that contain the name zae
# There are 86 names that contain the name zai
# There are 47 names that contain the name zak
# There are 52 names that contain the name zam
# There are 73 names that contain the name zan
# There are 103 names that contain the name zay
# There are 8 names that contain the name zea
# There are 8 names that contain the name zeb
# There are 6 names that contain the name zed
# There are 58 names that contain the name zen
# There are 2 names that contain the name zeo
# There are 5 names that contain the name zev
# There are 68 names that contain the name zia
# There are 5 names that contain the name ziv
# There are 2 names that contain the name zoa
# There are 13 names that contain the name zoe
# There are 5 names that contain the name zoi
# There are 1 names that contain the name zvi
# There are 22 names that contain the name zya
# There are 7 names that contain the name zye
# There are 8 names that contain the name zyn
# There are 10 names that contain the name aadi
# There are 5 names that contain the name aala
# There are 13 names that contain the name aara
# There are 25 names that contain the name aari
# There are 5 names that contain the name aaro
# There are 4 names that contain the name aava
# There are 4 names that contain the name abba
# There are 6 names that contain the name abbi
# There are 2 names that contain the name abby
# There are 12 names that contain the name abdi
# There are 2 names that contain the name abed
# There are 100 names that contain the name abel
# There are 3 names that contain the name abhi
# There are 1 names that contain the name abid
# There are 4 names that contain the name abie
# There are 8 names that contain the name abir
# There are 4 names that contain the name able
# There are 4 names that contain the name abou
# There are 9 names that contain the name abra
# There are 46 names that contain the name abri
# There are 6 names that contain the name acai
# There are 9 names that contain the name acee
# There are 7 names that contain the name acen
# There are 2 names that contain the name acer
# There are 19 names that contain the name acey
# There are 19 names that contain the name acie
# There are 3 names that contain the name acre
# There are 5 names that contain the name acyn
# There are 3 names that contain the name adah
# There are 62 names that contain the name adal
# There are 11 names that contain the name adam
# There are 14 names that contain the name adan
# There are 20 names that contain the name adar
# There are 17 names that contain the name adda
# There are 28 names that contain the name addi
# There are 11 names that contain the name addy
# There are 2 names that contain the name adea
# There are 64 names that contain the name adel
# There are 2 names that contain the name adem
# There are 29 names that contain the name aden
# There are 23 names that contain the name adia
# There are 2 names that contain the name adib
# There are 17 names that contain the name adil
# There are 12 names that contain the name adin
# There are 16 names that contain the name adir
# There are 1 names that contain the name adiv
# There are 1 names that contain the name adja
# There are 3 names that contain the name adna
# There are 2 names that contain the name adom
# There are 18 names that contain the name adon
# There are 17 names that contain the name ador
# There are 48 names that contain the name adri
# There are 6 names that contain the name adya
# There are 11 names that contain the name adyn
# There are 49 names that contain the name aela
# There are 1 names that contain the name aero
# There are 3 names that contain the name aeva
# There are 2 names that contain the name afia
# There are 1 names that contain the name afra
# There are 3 names that contain the name agam
# There are 7 names that contain the name ahad
# There are 25 names that contain the name ahan
# There are 13 names that contain the name ahil
# There are 27 names that contain the name ahmi
# There are 14 names that contain the name ahna
# There are 29 names that contain the name ahni
# There are 11 names that contain the name ahri
# There are 33 names that contain the name aida
# There are 47 names that contain the name aide
# There are 22 names that contain the name aidy
# There are 9 names that contain the name aija
# There are 8 names that contain the name aika
# There are 2 names that contain the name aiko
# There are 87 names that contain the name aila
# There are 19 names that contain the name aili
# There are 20 names that contain the name ailo
# There are 50 names that contain the name aily
# There are 24 names that contain the name aima
# There are 11 names that contain the name aime
# There are 5 names that contain the name aimi
# There are 39 names that contain the name aina
# There are 39 names that contain the name aine
# There are 57 names that contain the name aira
# There are 13 names that contain the name airi
# There are 11 names that contain the name aisa
# There are 2 names that contain the name aiva
# There are 10 names that contain the name aivi
# There are 4 names that contain the name aivy
# There are 94 names that contain the name aiya
# There are 19 names that contain the name aiza
# There are 5 names that contain the name ajah
# There are 3 names that contain the name ajai
# There are 1 names that contain the name ajla
# There are 1 names that contain the name ajna
# There are 2 names that contain the name ajwa
# There are 35 names that contain the name akai
# There are 10 names that contain the name akan
# There are 8 names that contain the name aker
# There are 10 names that contain the name akhi
# There are 14 names that contain the name akia
# There are 7 names that contain the name akil
# There are 4 names that contain the name akim
# There are 17 names that contain the name akin
# There are 11 names that contain the name akir
# There are 3 names that contain the name akon
# There are 22 names that contain the name aksh
# There are 2 names that contain the name akur
# There are 2 names that contain the name alaa
# There are 53 names that contain the name alai
# There are 6 names that contain the name alam
# There are 93 names that contain the name alan
# There are 4 names that contain the name alba
# There are 4 names that contain the name albi
# There are 18 names that contain the name aldo
# There are 43 names that contain the name alea
# There are 6 names that contain the name alec
# There are 86 names that contain the name alee
# There are 15 names that contain the name alek
# There are 68 names that contain the name alen
# There are 3 names that contain the name aleo
# There are 42 names that contain the name alex
# There are 101 names that contain the name alia
# There are 40 names that contain the name alie
# There are 4 names that contain the name alif
# There are 4 names that contain the name alii
# There are 16 names that contain the name alik
# There are 14 names that contain the name alim
# There are 83 names that contain the name alin
# There are 59 names that contain the name alis
# There are 5 names that contain the name alix
# There are 17 names that contain the name aliz
# There are 39 names that contain the name alla
# There are 54 names that contain the name alli
# There are 25 names that contain the name ally
# There are 13 names that contain the name alma
# There are 40 names that contain the name alon
# There are 2 names that contain the name aloy
# There are 6 names that contain the name alta
# There are 7 names that contain the name alva
# There are 13 names that contain the name alvi
# There are 25 names that contain the name alya
# There are 133 names that contain the name alyn
# There are 25 names that contain the name alys
# There are 3 names that contain the name alyx
# There are 25 names that contain the name amai
# There are 1 names that contain the name amaj
# There are 22 names that contain the name amal
# There are 46 names that contain the name aman
# There are 195 names that contain the name amar
# There are 26 names that contain the name amay
# There are 3 names that contain the name amea
# There are 9 names that contain the name amed
# There are 29 names that contain the name amee
# There are 15 names that contain the name amei
# There are 46 names that contain the name amel
# There are 9 names that contain the name amen
# There are 41 names that contain the name amer
# There are 20 names that contain the name ames
# There are 9 names that contain the name amey
# There are 31 names that contain the name amia
# There are 27 names that contain the name amie
# There are 82 names that contain the name amil
# There are 31 names that contain the name amin
# There are 85 names that contain the name amir
# There are 3 names that contain the name amit
# There are 30 names that contain the name amma
# There are 9 names that contain the name ammi
# There are 4 names that contain the name ammy
# There are 1 names that contain the name amna
# There are 40 names that contain the name amon
# There are 36 names that contain the name amor
# There are 7 names that contain the name amra
# There are 11 names that contain the name amri
# There are 11 names that contain the name amry
# There are 2 names that contain the name amun
# There are 24 names that contain the name amya
# There are 18 names that contain the name amyr
# There are 8 names that contain the name anab
# There are 35 names that contain the name anai
# There are 6 names that contain the name anam
# There are 22 names that contain the name anas
# There are 13 names that contain the name anav
# There are 37 names that contain the name anay
# There are 58 names that contain the name ande
# There are 25 names that contain the name andi
# There are 18 names that contain the name andy
# There are 70 names that contain the name anel
# There are 77 names that contain the name ange
# There are 50 names that contain the name ania
# There are 13 names that contain the name anik
# There are 5 names that contain the name anir
# There are 39 names that contain the name anis
# There are 1 names that contain the name aniv
# There are 8 names that contain the name anja
# There are 362 names that contain the name anna
# There are 86 names that contain the name anne
# There are 126 names that contain the name anni
# There are 44 names that contain the name anny
# There are 5 names that contain the name ansa
# There are 65 names that contain the name ansh
# There are 16 names that contain the name anta
# There are 21 names that contain the name ante
# There are 42 names that contain the name anvi
# There are 38 names that contain the name anya
# There are 8 names that contain the name anyi
# There are 6 names that contain the name anze
# There are 1 names that contain the name aoki
# There are 1 names that contain the name aqib
# There are 16 names that contain the name aqua
# There are 6 names that contain the name arad
# There are 3 names that contain the name araf
# There are 31 names that contain the name arah
# There are 12 names that contain the name aram
# There are 19 names that contain the name aran
# There are 7 names that contain the name aras
# There are 4 names that contain the name arav
# There are 11 names that contain the name arch
# There are 5 names that contain the name arda
# There are 6 names that contain the name ardi
# There are 6 names that contain the name arek
# There are 42 names that contain the name arel
# There are 27 names that contain the name aren
# There are 3 names that contain the name ares
# There are 1 names that contain the name arfa
# There are 11 names that contain the name arha
# There are 195 names that contain the name aria
# There are 14 names that contain the name aric
# There are 123 names that contain the name arie
# There are 3 names that contain the name arif
# There are 16 names that contain the name arii
# There are 11 names that contain the name arik
# There are 43 names that contain the name arin
# There are 62 names that contain the name ario
# There are 83 names that contain the name aris
# There are 2 names that contain the name ariv
# There are 11 names that contain the name ariz
# There are 4 names that contain the name arka
# There are 25 names that contain the name arla
# There are 58 names that contain the name arli
# There are 44 names that contain the name arlo
# There are 37 names that contain the name arly
# There are 9 names that contain the name arna
# There are 13 names that contain the name arne
# There are 4 names that contain the name arno
# There are 17 names that contain the name aron
# There are 74 names that contain the name arri
# There are 40 names that contain the name arsh
# There are 20 names that contain the name arth
# There are 22 names that contain the name arti
# There are 4 names that contain the name arun
# There are 22 names that contain the name arvi
# There are 6 names that contain the name arwa
# There are 60 names that contain the name arya
# There are 13 names that contain the name arye
# There are 15 names that contain the name aryn
# There are 2 names that contain the name aryo
# There are 5 names that contain the name arzo
# There are 1 names that contain the name arzu
# There are 1 names that contain the name asad
# There are 1 names that contain the name asaf
# There are 6 names that contain the name asah
# There are 8 names that contain the name asai
# There are 24 names that contain the name asan
# There are 2 names that contain the name asar
# There are 7 names that contain the name asel
# There are 2 names that contain the name asem
# There are 15 names that contain the name asen
# There are 4 names that contain the name aser
# There are 3 names that contain the name aset
# There are 56 names that contain the name asha
# There are 20 names that contain the name ashe
# There are 49 names that contain the name asia
# There are 8 names that contain the name asil
# There are 16 names that contain the name asim
# There are 20 names that contain the name asir
# There are 5 names that contain the name asli
# There are 6 names that contain the name asly
# There are 5 names that contain the name asma
# There are 8 names that contain the name asmi
# There are 16 names that contain the name ason
# There are 5 names that contain the name asra
# There are 19 names that contain the name asta
# There are 1 names that contain the name asun
# There are 9 names that contain the name asya
# There are 2 names that contain the name atai
# There are 51 names that contain the name atal
# There are 4 names that contain the name atem
# There are 3 names that contain the name atif
# There are 7 names that contain the name atla
# There are 3 names that contain the name atli
# There are 5 names that contain the name atum
# There are 9 names that contain the name atzi
# There are 9 names that contain the name audi
# There are 7 names that contain the name auna
# There are 8 names that contain the name auni
# There are 13 names that contain the name aura
# There are 43 names that contain the name auri
# There are 7 names that contain the name auro
# There are 9 names that contain the name aury
# There are 2 names that contain the name avaa
# There are 3 names that contain the name avah
# There are 52 names that contain the name avan
# There are 11 names that contain the name avea
# There are 16 names that contain the name avel
# There are 37 names that contain the name aven
# There are 3 names that contain the name avet
# There are 14 names that contain the name avey
# There are 51 names that contain the name avia
# There are 43 names that contain the name avie
# There are 5 names that contain the name avik
# There are 30 names that contain the name avin
# There are 7 names that contain the name avir
# There are 17 names that contain the name avis
# There are 1 names that contain the name aviv
# There are 44 names that contain the name avon
# There are 3 names that contain the name avra
# There are 14 names that contain the name avri
# There are 3 names that contain the name avry
# There are 22 names that contain the name avya
# There are 11 names that contain the name avyn
# There are 1 names that contain the name awab
# There are 5 names that contain the name axel
# There are 5 names that contain the name axen
# There are 6 names that contain the name axle
# There are 1 names that contain the name ayad
# There are 99 names that contain the name ayah
# There are 1 names that contain the name ayak
# There are 79 names that contain the name ayan
# There are 8 names that contain the name ayat
# There are 45 names that contain the name ayce
# There are 20 names that contain the name ayda
# There are 5 names that contain the name aydn
# There are 5 names that contain the name ayen
# There are 142 names that contain the name ayla
# There are 92 names that contain the name ayli
# There are 19 names that contain the name ayma
# There are 10 names that contain the name ayni
# There are 20 names that contain the name ayon
# There are 25 names that contain the name ayra
# There are 9 names that contain the name aysa
# There are 26 names that contain the name ayse
# There are 3 names that contain the name ayur
# There are 5 names that contain the name ayva
# There are 5 names that contain the name ayza
# There are 15 names that contain the name azai
# There are 23 names that contain the name azal
# There are 2 names that contain the name azam
# There are 10 names that contain the name azan
# There are 69 names that contain the name azar
# There are 27 names that contain the name azel
# There are 3 names that contain the name azer
# There are 15 names that contain the name azia
# There are 7 names that contain the name azil
# There are 5 names that contain the name azim
# There are 10 names that contain the name azir
# There are 4 names that contain the name aziz
# There are 15 names that contain the name azly
# There are 3 names that contain the name azon
# There are 5 names that contain the name azra
# There are 2 names that contain the name azul
# There are 12 names that contain the name azur
# There are 4 names that contain the name baaz
# There are 2 names that contain the name baba
# There are 2 names that contain the name baby
# There are 1 names that contain the name bahr
# There are 3 names that contain the name bain
# There are 2 names that contain the name bair
# There are 1 names that contain the name bakr
# There are 4 names that contain the name bali
# There are 1 names that contain the name bana
# There are 2 names that contain the name bane
# There are 4 names that contain the name bani
# There are 5 names that contain the name bari
# There are 6 names that contain the name bash
# There are 2 names that contain the name baya
# There are 1 names that contain the name bear
# There are 13 names that contain the name beau
# There are 17 names that contain the name beck
# There are 9 names that contain the name bela
# There are 119 names that contain the name bell
# There are 4 names that contain the name bena
# There are 5 names that contain the name beni
# There are 1 names that contain the name benz
# There are 40 names that contain the name berl
# There are 38 names that contain the name bert
# There are 2 names that contain the name bess
# There are 35 names that contain the name beth
# There are 2 names that contain the name beza
# There are 2 names that contain the name bibi
# There are 2 names that contain the name biel
# There are 5 names that contain the name bill
# There are 5 names that contain the name bina
# There are 2 names that contain the name blin
# There are 3 names that contain the name bode
# There are 3 names that contain the name bodi
# There are 1 names that contain the name boon
# There are 2 names that contain the name bora
# There are 2 names that contain the name bowe
# There are 15 names that contain the name brad
# There are 16 names that contain the name brae
# There are 1 names that contain the name bram
# There are 32 names that contain the name bran
# There are 18 names that contain the name brax
# There are 41 names that contain the name bray
# There are 10 names that contain the name brea
# There are 25 names that contain the name bree
# There are 30 names that contain the name bren
# There are 6 names that contain the name bret
# There are 11 names that contain the name brex
# There are 17 names that contain the name brey
# There are 37 names that contain the name bria
# There are 45 names that contain the name brie
# There are 3 names that contain the name brio
# There are 10 names that contain the name brix
# There are 3 names that contain the name broc
# There are 10 names that contain the name brya
# There are 5 names that contain the name brye
# There are 26 names that contain the name bryn
# There are 3 names that contain the name buck
# There are 3 names that contain the name cabe
# There are 5 names that contain the name cade
# There are 2 names that contain the name cady
# There are 15 names that contain the name cael
# There are 4 names that contain the name caia
# There are 4 names that contain the name cain
# There are 4 names that contain the name cait
# There are 10 names that contain the name cala
# There are 17 names that contain the name cale
# There are 29 names that contain the name cali
# There are 5 names that contain the name caly
# There are 21 names that contain the name cami
# There are 3 names that contain the name camp
# There are 3 names that contain the name cana
# There are 1 names that contain the name cane
# There are 3 names that contain the name cara
# There are 31 names that contain the name cari
# There are 51 names that contain the name carl
# There are 1 names that contain the name cary
# There are 6 names that contain the name case
# There are 14 names that contain the name cash
# There are 5 names that contain the name casi
# There are 13 names that contain the name cass
# There are 6 names that contain the name cate
# There are 1 names that contain the name cato
# There are 1 names that contain the name cece
# There are 12 names that contain the name ceci
# There are 7 names that contain the name cela
# There are 27 names that contain the name cely
# There are 1 names that contain the name cera
# There are 2 names that contain the name chad
# There are 10 names that contain the name chai
# There are 36 names that contain the name chan
# There are 1 names that contain the name chau
# There are 2 names that contain the name chaz
# There are 12 names that contain the name chen
# There are 3 names that contain the name chet
# There are 1 names that contain the name chip
# There are 21 names that contain the name cian
# There are 1 names that contain the name cici
# There are 15 names that contain the name ciel
# There are 2 names that contain the name ciri
# There are 4 names that contain the name clay
# There are 3 names that contain the name clea
# There are 3 names that contain the name cleo
# There are 1 names that contain the name clio
# There are 1 names that contain the name cloe
# There are 1 names that contain the name coal
# There are 2 names that contain the name cobe
# There are 5 names that contain the name cobi
# There are 1 names that contain the name coby
# There are 1 names that contain the name coda
# There are 2 names that contain the name codi
# There are 14 names that contain the name cole
# There are 2 names that contain the name colm
# There are 7 names that contain the name colt
# There are 8 names that contain the name cope
# There are 14 names that contain the name cora
# There are 7 names that contain the name cord
# There are 12 names that contain the name cori
# There are 6 names that contain the name cort
# There are 2 names that contain the name cory
# There are 3 names that contain the name cove
# There are 7 names that contain the name cree
# There are 2 names that contain the name crew
# There are 22 names that contain the name cris
# There are 3 names that contain the name cruz
# There are 1 names that contain the name curt
# There are 4 names that contain the name cyan
# There are 2 names that contain the name cyla
# There are 3 names that contain the name cyle
# There are 1 names that contain the name cyra
# There are 3 names that contain the name cyre
# There are 1 names that contain the name czar
# There are 3 names that contain the name dace
# There are 10 names that contain the name dael
# There are 2 names that contain the name dago
# There are 2 names that contain the name dain
# There are 9 names that contain the name dair
# There are 1 names that contain the name daja
# There are 42 names that contain the name dale
# There are 41 names that contain the name dali
# There are 41 names that contain the name daly
# There are 6 names that contain the name dame
# There are 16 names that contain the name dana
# There are 13 names that contain the name dane
# There are 33 names that contain the name dani
# There are 10 names that contain the name dany
# There are 8 names that contain the name dara
# There are 48 names that contain the name dari
# There are 15 names that contain the name dash
# There are 9 names that contain the name dave
# There are 37 names that contain the name davi
# There are 2 names that contain the name davy
# There are 1 names that contain the name daxx
# There are 23 names that contain the name daya
# There are 12 names that contain the name dean
# There are 3 names that contain the name deem
# There are 7 names that contain the name deen
# There are 2 names that contain the name deja
# There are 40 names that contain the name dela
# There are 26 names that contain the name dell
# There are 21 names that contain the name demi
# ...
# There are 1 names that contain the name winterr
# There are 1 names that contain the name wrenlyn
# There are 2 names that contain the name xandria
# There are 1 names that contain the name xandros
# There are 1 names that contain the name xzander
# There are 1 names that contain the name xzavier
# There are 3 names that contain the name yamilet
# There are 1 names that contain the name yuliett
# There are 8 names that contain the name zabella
# There are 4 names that contain the name zachari
# There are 1 names that contain the name zachary
# There are 1 names that contain the name zakaria
# There are 1 names that contain the name zakarya
# There are 1 names that contain the name zalayah
# There are 2 names that contain the name zaleigh
# There are 1 names that contain the name zaleyah
# There are 1 names that contain the name zaliyah
# There are 2 names that contain the name zamaria
# There are 1 names that contain the name zaniyla
# There are 2 names that contain the name zariyah
# There are 1 names that contain the name zayanna
# There are 1 names that contain the name zayveon
# There are 1 names that contain the name zayvier
# There are 2 names that contain the name zayvion
# There are 1 names that contain the name zendaya
# There are 1 names that contain the name zunaira
# There are 1 names that contain the name aashrith
# There are 1 names that contain the name abdullah
# There are 1 names that contain the name abrianna
# There are 1 names that contain the name abriella
# There are 2 names that contain the name abrielle
# There are 1 names that contain the name adaleigh
# There are 1 names that contain the name adalynne
# There are 2 names that contain the name addalynn
# There are 1 names that contain the name addeline
# There are 1 names that contain the name addelynn
# There are 2 names that contain the name addilynn
# There are 1 names that contain the name adelaine
# There are 1 names that contain the name adeleine
# There are 1 names that contain the name adelynne
# There are 1 names that contain the name adilynne
# There are 1 names that contain the name ahmarion
# There are 1 names that contain the name alayshia
# There are 1 names that contain the name alaysiah
# There are 7 names that contain the name alexandr
# There are 1 names that contain the name alhassan
# There are 1 names that contain the name aliyanna
# There are 2 names that contain the name allister
# There are 1 names that contain the name amariyah
# There are 1 names that contain the name amberlyn
# There are 2 names that contain the name amillian
# There are 2 names that contain the name amillion
# There are 3 names that contain the name amiracle
# There are 1 names that contain the name anagrace
# There are 1 names that contain the name analeigh
# There are 1 names that contain the name angelene
# There are 1 names that contain the name angelina
# There are 2 names that contain the name angeline
# There are 2 names that contain the name annabell
# There are 1 names that contain the name annalaya
# There are 1 names that contain the name annalynn
# There are 3 names that contain the name arabella
# There are 2 names that contain the name arabelle
# There are 1 names that contain the name araoluwa
# There are 1 names that contain the name aribella
# There are 1 names that contain the name aribelle
# There are 1 names that contain the name aricella
# There are 1 names that contain the name armoniee
# There are 4 names that contain the name augustin
# There are 1 names that contain the name aurelian
# There are 1 names that contain the name aurielle
# There are 1 names that contain the name aylarose
# There are 1 names that contain the name benedict
# There are 1 names that contain the name blakelyn
# There are 1 names that contain the name blessing
# There are 1 names that contain the name bonnibel
# There are 1 names that contain the name boubacar
# There are 1 names that contain the name brecklyn
# There are 1 names that contain the name bridgett
# There are 2 names that contain the name brooklyn
# There are 1 names that contain the name carletta
# There are 1 names that contain the name cataleya
# There are 1 names that contain the name celestia
# There are 1 names that contain the name chrislyn
# There are 2 names that contain the name christel
# There are 5 names that contain the name christia
# There are 2 names that contain the name christin
# There are 1 names that contain the name courtlyn
# There are 2 names that contain the name cristian
# There are 1 names that contain the name cristina
# There are 2 names that contain the name darasimi
# There are 2 names that contain the name demetrio
# There are 1 names that contain the name eleanora
# There are 2 names that contain the name elisabet
# There are 1 names that contain the name eliyanna
# There are 3 names that contain the name ellarose
# There are 1 names that contain the name ellianna
# There are 1 names that contain the name ellieann
# There are 2 names that contain the name emberlyn
# There are 1 names that contain the name emiliano
# There are 1 names that contain the name emmalynn
# There are 3 names that contain the name emmanuel
# There are 1 names that contain the name enderson
# There are 2 names that contain the name ensleigh
# There are 1 names that contain the name enzleigh
# There are 1 names that contain the name eriberto
# There are 1 names that contain the name erioluwa
# There are 2 names that contain the name estefani
# There are 5 names that contain the name evangeli
# There are 1 names that contain the name evangelo
# There are 1 names that contain the name faithlyn
# There are 1 names that contain the name fernanda
# There are 1 names that contain the name fernando
# There are 1 names that contain the name franklyn
# There are 3 names that contain the name frederic
# There are 3 names that contain the name gabriell
# There are 1 names that contain the name gianluca
# There are 1 names that contain the name giovanni
# There are 1 names that contain the name giovonni
# There are 2 names that contain the name gracelyn
# There are 1 names that contain the name harleigh
# There are 1 names that contain the name harmonie
# There are 1 names that contain the name harriett
# There are 1 names that contain the name hawthorn
# There are 1 names that contain the name hayleigh
# There are 1 names that contain the name heavenly
# There are 1 names that contain the name hendrick
# There are 1 names that contain the name hutchins
# There are 2 names that contain the name illianna
# There are 1 names that contain the name illyanna
# There are 4 names that contain the name isabella
# There are 2 names that contain the name izabella
# There are 1 names that contain the name izabelle
# There are 1 names that contain the name jackelin
# There are 1 names that contain the name jancarlo
# There are 1 names that contain the name jaquelin
# There are 1 names that contain the name jessalyn
# There are 1 names that contain the name jonathan
# There are 1 names that contain the name josselin
# There are 1 names that contain the name joycelyn
# There are 1 names that contain the name julianni
# There are 1 names that contain the name julieann
# There are 1 names that contain the name karlette
# There are 1 names that contain the name kataleya
# There are 2 names that contain the name katerina
# There are 3 names that contain the name katherin
# There are 1 names that contain the name kaylanni
# There are 1 names that contain the name kaylonni
# There are 1 names that contain the name keiliany
# There are 1 names that contain the name kellyann
# There are 1 names that contain the name kendalyn
# There are 2 names that contain the name kenleigh
# There are 1 names that contain the name khadeeja
# There are 1 names that contain the name khaleesi
# There are 2 names that contain the name kimberli
# There are 2 names that contain the name kimberly
# There are 2 names that contain the name kinleigh
# There are 1 names that contain the name kourtlyn
# There are 3 names that contain the name kristian
# There are 1 names that contain the name kristoff
# There are 1 names that contain the name krystian
# There are 1 names that contain the name lailonni
# There are 2 names that contain the name lakelynn
# There are 2 names that contain the name leighann
# There are 1 names that contain the name lesandro
# There are 1 names that contain the name lilianna
# There are 2 names that contain the name lilliann
# There are 2 names that contain the name lillyann
# There are 2 names that contain the name lisandra
# There are 1 names that contain the name lisandro
# There are 1 names that contain the name livianna
# There are 7 names that contain the name lizabeth
# There are 1 names that contain the name lizandro
# There are 1 names that contain the name lorianna
# There are 2 names that contain the name mackenzi
# There are 1 names that contain the name madalynn
# There are 1 names that contain the name maddalyn
# There are 1 names that contain the name maddelyn
# There are 1 names that contain the name maddilyn
# There are 1 names that contain the name madelein
# There are 1 names that contain the name madelynn
# There are 1 names that contain the name madilynn
# There are 1 names that contain the name maevelyn
# There are 2 names that contain the name magdalen
# There are 1 names that contain the name magdalyn
# There are 1 names that contain the name malaysia
# There are 2 names that contain the name manuella
# There are 1 names that contain the name marcello
# There are 1 names that contain the name mardoche
# There are 5 names that contain the name margaret
# There are 1 names that contain the name marianna
# There are 2 names that contain the name maribell
# There are 1 names that contain the name marielle
# There are 1 names that contain the name marionna
# There are 1 names that contain the name maryelle
# There are 1 names that contain the name mattilyn
# There are 2 names that contain the name michaela
# There are 2 names that contain the name milianna
# There are 2 names that contain the name milliana
# There are 3 names that contain the name milliano
# There are 2 names that contain the name mirabell
# There are 1 names that contain the name miroslav
# There are 4 names that contain the name mohammad
# There are 1 names that contain the name mouhamad
# There are 13 names that contain the name muhammad
# There are 1 names that contain the name nataliya
# There are 1 names that contain the name octavian
# There are 1 names that contain the name olaoluwa
# There are 2 names that contain the name orabelle
# There are 2 names that contain the name penelope
# There are 1 names that contain the name penelopi
# There are 2 names that contain the name peregrin
# There are 1 names that contain the name princess
# There are 1 names that contain the name priyansh
# There are 2 names that contain the name racelynn
# There are 1 names that contain the name raeleigh
# There are 1 names that contain the name raileigh
# There are 1 names that contain the name rayleigh
# There are 1 names that contain the name rayshawn
# There are 2 names that contain the name reighlyn
# There are 2 names that contain the name renleigh
# There are 2 names that contain the name riverlyn
# There are 1 names that contain the name riyanshi
# There are 1 names that contain the name roderick
# There are 1 names that contain the name rosalind
# There are 1 names that contain the name rosalynn
# There are 1 names that contain the name rosealyn
# There are 1 names that contain the name roselynn
# There are 1 names that contain the name rosemari
# There are 1 names that contain the name rynleigh
# There are 2 names that contain the name savannah
# There are 1 names that contain the name scarleth
# There are 3 names that contain the name scarlett
# There are 1 names that contain the name scottlyn
# There are 1 names that contain the name seraphim
# There are 1 names that contain the name shivansh
# There are 1 names that contain the name siddhant
# There are 1 names that contain the name sinclair
# There are 1 names that contain the name skarlett
# There are 1 names that contain the name starlett
# There are 1 names that contain the name stefania
# There are 1 names that contain the name stefanie
# There are 3 names that contain the name stephani
# There are 1 names that contain the name symphani
# There are 1 names that contain the name symphoni
# There are 1 names that contain the name taleigha
# There are 1 names that contain the name theodoro
# There are 2 names that contain the name timberly
# There are 1 names that contain the name vaishnav
# There are 4 names that contain the name valentin
# There are 1 names that contain the name valerian
# There are 1 names that contain the name vanshika
# There are 4 names that contain the name victoria
# There are 1 names that contain the name victorio
# There are 1 names that contain the name viridian
# There are 3 names that contain the name wendolyn
# There are 1 names that contain the name yamilett
# There are 2 names that contain the name zacharia
# There are 1 names that contain the name zackaria
# There are 1 names that contain the name zakariya
# There are 1 names that contain the name zariella
# There are 1 names that contain the name zecharia
# There are 1 names that contain the name zipporah
# There are 1 names that contain the name aleksandr
# There are 1 names that contain the name alexander
# There are 1 names that contain the name alexandre
# There are 1 names that contain the name alexandro
# There are 1 names that contain the name angelique
# There are 1 names that contain the name annaleigh
# There are 1 names that contain the name annamaria
# There are 1 names that contain the name antavious
# There are 1 names that contain the name archibald
# There are 1 names that contain the name aristella
# There are 5 names that contain the name arrington
# There are 1 names that contain the name artavious
# There are 1 names that contain the name averleigh
# There are 1 names that contain the name beautiful
# There are 1 names that contain the name bellarose
# There are 1 names that contain the name brookelyn
# There are 1 names that contain the name brooklynn
# There are 1 names that contain the name catherine
# There are 3 names that contain the name christian
# There are 3 names that contain the name christoph
# There are 1 names that contain the name corinthia
# There are 1 names that contain the name ekaterina
# There are 4 names that contain the name elizabeth
# There are 1 names that contain the name ellagrace
# There are 1 names that contain the name ellamarie
# There are 1 names that contain the name ellington
# There are 1 names that contain the name emberlynn
# There are 2 names that contain the name evangelin
# There are 1 names that contain the name giancarlo
# There are 1 names that contain the name gracelynn
# There are 1 names that contain the name guadalupe
# There are 1 names that contain the name gwendalyn
# There are 2 names that contain the name gwendolyn
# There are 1 names that contain the name jacquelin
# There are 2 names that contain the name jacquelyn
# There are 1 names that contain the name jeancarlo
# There are 1 names that contain the name jerusalem
# There are 1 names that contain the name juwayriya
# There are 1 names that contain the name katherine
# There are 1 names that contain the name kimberlyn
# There are 1 names that contain the name lakeleigh
# There are 1 names that contain the name lissandra
# There are 1 names that contain the name margarett
# There are 1 names that contain the name mariangel
# There are 2 names that contain the name monserrat
# There are 1 names that contain the name nastassia
# There are 2 names that contain the name oluwadara
# There are 1 names that contain the name oluwatobi
# There are 1 names that contain the name riverlynn
# There are 2 names that contain the name sebastian
# There are 1 names that contain the name siddharth
# There are 1 names that contain the name stephanie
# There are 1 names that contain the name timberlyn
# There are 1 names that contain the name armanullah
# There are 1 names that contain the name aryanreddy
# There are 1 names that contain the name christabel
# There are 2 names that contain the name christophe
# There are 2 names that contain the name constantin
# There are 3 names that contain the name konstantin
# There are 2 names that contain the name maximilian
# There are 1 names that contain the name montserrat
# There are 1 names that contain the name maximillian

# %%
l = ['noah', 'mark', 'john']

for number1 in l:
    for number2 in l:
        print(f"Number 1: {number1}; number 2: {number2}")
# Out:
# Number 1: noah; number 2: noah
# Number 1: noah; number 2: mark
# Number 1: noah; number 2: john
# Number 1: mark; number 2: noah
# Number 1: mark; number 2: mark
# Number 1: mark; number 2: john
# Number 1: john; number 2: noah
# Number 1: john; number 2: mark
# Number 1: john; number 2: john

# %% [markdown]
# What is the most popular girls' name that is also a boys' name?

# %% [markdown]
# Write a function that takes a prefix as input and prints the number of boys and girls with that prefix (e.g., get_names("m") would list all names that start with "m" and get_names("ma") would only list those that start with "ma").
