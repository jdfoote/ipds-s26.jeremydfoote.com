# %% [markdown]
# ## PY4E Ch 9

# %% [markdown]
# Exercise 2: Write a program that categorizes each mail message by which day of the week the commit was done. To do this look for lines that start with “From”, then look for the third word and keep a running count of each of the days of the week. At the end of the program print out the contents of your dictionary (order does not matter).
#
# Sample Line:
#
# ```
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# ```
#
# Sample Execution:
#
# ```python
#     python dow.py
#     Enter a file name: mbox-short.txt
#     {'Fri': 20, 'Thu': 6, 'Sat': 1}
# ```

# %% [markdown]
# Exercise 3: Write a program to read through a mail log, build a histogram using a dictionary to count how many messages have come from each email address, and print the dictionary.
#
#     Enter file name: mbox-short.txt
#     {'gopal.ramasammycook@gmail.com': 1, 'louis@media.berkeley.edu': 3,
#     'cwen@iupui.edu': 5, 'antranig@caret.cam.ac.uk': 1,
#     'rjlowe@iupui.edu': 2, 'gsilver@umich.edu': 3,
#     'david.horwitz@uct.ac.za': 4, 'wagnermr@iupui.edu': 1,
#     'zqian@umich.edu': 4, 'stephen.marquard@uct.ac.za': 2,
#     'ray@media.berkeley.edu': 1}

# %% [markdown]
# Exercise 4: Add code to the above program to figure out who has the most messages in the file. After all the data has been read and the dictionary has been created, look through the dictionary using a maximum loop (see Chapter 5: Maximum and minimum loops) to find who has the most messages and print how many messages the person has.
#
#     Enter a file name: mbox-short.txt
#     cwen@iupui.edu 5
#
#     Enter a file name: mbox.txt
#     zqian@umich.edu 195

# %%
email_count = {}
with open('./mbox-short.txt', 'r') as f:
    for line in f:
        if line[:5] == "From ":
            line_list = line.split()
            email = line_list[1]
            if email not in email_count:
                email_count[email] = 1
            else:
                email_count[email] = email_count[email] + 1


max_count = 0
max_email = None

for email in email_count:
    curr_count = email_count[email]
    if curr_count > max_count:
        max_count = curr_count
        max_email = email

print(f"The most prolific emailer was {max_email}, who sent {max_count} emails")
# Out:
# The most prolific emailer was cwen@iupui.edu, who sent 5 emails

# %% [markdown]
# ## 9.5
#
# This program records the domain name (instead of the address) where the message was sent from instead of who the mail came from (i.e., the whole email address). At the end of the program, print out the contents of your dictionary.

# %% [markdown]
# ## PY4E Ch 10

# %% [markdown]
# Exercise 1: Revise a previous program as follows: Read and parse the “From” lines and pull out the addresses from the line. Count the number of messages from each person using a dictionary.
#
# After all the data has been read, print the person with the most commits by creating a list of (count, email) tuples from the dictionary. Then sort the list in reverse order and print out the person who has the most commits.
#
#     Sample Line:
#     From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
#     Enter a file name: mbox-short.txt
#     cwen@iupui.edu 5
#
#     Enter a file name: mbox.txt
#     zqian@umich.edu 195

# %%
email_count = {}
with open('./mbox-short.txt', 'r') as f:
    for line in f:
        if line[:5] == "From ":
            line_list = line.split()
            email = line_list[1]
            if email not in email_count:
                email_count[email] = 1
            else:
                email_count[email] = email_count[email] + 1
        else:
            continue

emails_list = []
for email, count in email_count.items():
    emails_list.append((count, email))

sorted(emails_list, reverse=True)
# Out:
# [(5, 'cwen@iupui.edu'),
#  (4, 'zqian@umich.edu'),
#  (4, 'david.horwitz@uct.ac.za'),
#  (3, 'louis@media.berkeley.edu'),
#  (3, 'gsilver@umich.edu'),
#  (2, 'stephen.marquard@uct.ac.za'),
#  (2, 'rjlowe@iupui.edu'),
#  (1, 'wagnermr@iupui.edu'),
#  (1, 'ray@media.berkeley.edu'),
#  (1, 'gopal.ramasammycook@gmail.com'),
#  (1, 'antranig@caret.cam.ac.uk')]

# %% [markdown]
# Exercise 2: This program counts the distribution of the hour of the day for each of the messages. You can pull the hour from the “From” line by finding the time string and then splitting that string into parts using the colon character. Once you have accumulated the counts for each hour, print out the counts, one per line, sorted by hour as shown below.
#
#     python timeofday.py
#     Enter a file name: mbox-short.txt
#     04 3
#     06 1
#     07 1
#     09 2
#     10 3
#     11 6
#     14 1
#     15 2
#     16 4
#     17 2
#     18 1
#     19 1

# %% [markdown]
# ### 10.3
#
# Exercise 3: Write a program that reads a file and prints the letters in decreasing order of frequency.
#
# Your program should convert all the input to lower case and only count the letters a-z. Your program should not count spaces, digits, punctuation, or anything other than the letters a-z. Find text samples from several different languages and see how letter frequency varies between languages. Compare your results with the tables at https://wikipedia.org/wiki/Letter_frequencies.

# %%
good_letters = 'abcdefghijklmnopqrstuvwxyz'
#good_letters = 'aeiou'
letter_counts = {}
with open('mbox-short.txt', 'r') as f:
    for line in f:
        for letter in line.lower():
            if letter not in good_letters:
               # if letter not in letter_counts:
               #     letter_counts[letter] = 1
               # else:
               #     letter_counts[letter] += 1
               letter_counts[letter] = letter_counts.get(letter, 0) + 1

count_tuples = []
for letter, count in letter_counts.items():
    count_tuples.append((count, letter))
sorted(count_tuples, reverse=True)
# Out:
# [(7726, ' '),
#  (3856, '.'),
#  (3466, '0'),
#  (3053, '-'),
#  (1923, '1'),
#  (1921, '/'),
#  (1910, '\n'),
#  (1750, ':'),
#  (1603, '2'),
#  (1044, '4'),
#  (986, '8'),
#  (852, '3'),
#  (728, '5'),
#  (609, ')'),
#  (609, '('),
#  (559, '7'),
#  (514, '9'),
#  (470, '6'),
#  (436, '\t'),
#  (336, '@'),
#  (324, ';'),
#  (282, ','),
#  (243, ']'),
#  (243, '['),
#  (166, '>'),
#  (135, '='),
#  (135, '<'),
#  (84, '+'),
#  (56, '_'),
#  (27, '?'),
#  (27, '&'),
#  (21, '|'),
#  (8, '"'),
#  (6, "'"),
#  (4, '~'),
#  (1, '#')]

# %% [markdown]
# ## Jeremy's Notebook Exercises
#
# 1. See if you can modify the code above to count how often each word appears instead.

# %%
string = """
I have been one acquainted with the night.
I have walked out in rain—and back in rain.
I have outwalked the furthest city light.

I have looked down the saddest city lane.
I have passed by the watchman on his beat
And dropped my eyes, unwilling to explain.

I have stood still and stopped the sound of feet
When far away an interrupted cry
Came over houses from another street,

But not to call me back or say good-bye;
And further still at an unearthly height,
One luminary clock against the sky

Proclaimed the time was neither wrong nor right. 
I have been one acquainted with the night.
"""

string = string.lower()
string = string.replace('—', ' ')
string = string.replace(',', '')

# %% [markdown]
# 2. Reuse and modify the code above so that it prints a dictionary of the total population of cities that start with each letter of the alphabet.

# %% [markdown]
# ## Babynames
#
#
# Search for your own name. Are there both boys and girls that have your name? Is it more popular for one group than for the other?

# %%
NAMES_LIST = "baby_names/yob2022.txt"

# Creates two empty dictionaries - one for boys and one for girls
boys = {}
girls = {}

for line in open(NAMES_LIST, 'r').readlines():
    name, sex, count = line.strip().split(",")
    count = int(count)
    # Puts data about females in one dictionary and about males in the other
    if sex == "F":
        girls[name.lower()] = count
    elif sex == "M":
        boys[name.lower()] = count

# %% [markdown]
# Are there more boys' names or girls' names? What about for particular first letters? What about for ''every'' first letter?

# %% [markdown]
# What is the longest name in the dataset?

# %% [markdown]
# What is the most common name and how often does it occur?

# %% [markdown]
# What is the least common name and how often does it occur? Does that concern you?

# %% [markdown]
# How many boys and girls are described in the dataset (i.e., how many boys and girls born in 2018 have names given to at least four others)?

# %% [markdown]
# How many boys' names are also girls' names? How many girls' names are also boys' names?

# %% [markdown]
# How many names are subsets of other names?

# %%
all_names = list(boys.keys()) + list(girls.keys())

word_lengths = []

for name in all_names:
    name_len = len(name)
    word_lengths.append((name_len, name))

word_lengths = sorted(word_lengths)

subset_names = {}
index = 0

for count1, name1 in word_lengths:
    superset_names = []
    index = index + 1
    for count2, name2 in word_lengths[index:]:
        if count1 == count2:
            continue
        elif name1 in name2:
            superset_names.append(name2)
        else:
            continue
    if len(superset_names) > 0:
        subset_names[name1] = superset_names

print(subset_names)
# Out:
# {'aj': ['aja', 'kaj', 'raj', 'taj', 'taj', 'ajah', 'ajai', 'ajak', 'ajax', 'ajay', 'ajit', 'ajla', 'ajna', 'ajwa', 'amaj', 'daja', 'fajr', 'haji', 'kaja', 'maja', 'majd', 'maji', 'naja', 'najd', 'naje', 'naji', 'najm', 'raja', 'raja', 'raji', 'saja', 'saje', 'taaj', 'tajh', 'taji', 'vraj', 'ajani', 'ajani', 'ajdin', 'ajeet', 'ajuni', 'alaja', 'dajon', 'fajar', 'hajar', 'hajer', 'hajra', 'kajai', 'majai', 'majed', 'majic', 'majid', 'majik', 'major', 'majur', 'miraj', 'miraj', 'najae', 'najah', 'najat', 'najee', 'najib', 'najir', 'najla', 'najma', 'najwa', 'ohaji', 'rajah', 'rajah', 'rajan', 'rajon', 'retaj', 'ritaj', 'sahaj', 'sajan', 'sajid', 'samaj', 'sehaj', 'sehaj', 'semaj', 'semaj', 'siraj', 'suraj', 'viraj', 'ajahni', 'ajanae', 'ajooni', 'ajream', 'akshaj', 'alajah', 'aviraj', 'dajour', 'dajuan', 'emmajo', 'faraja', 'gurtaj', 'hajara', 'hajira', 'hajoon', 'jajuan', 'jasraj', 'kajani', 'kajuan', 'majeed', 'majhor', 'majour', 'manraj', 'manraj', 'mehraj', 'najour', 'prajna', 'rajvir', 'saajid', 'sajjad', 'samraj', 'sartaj', 'taraji', 'trajan', 'viraaj', 'wajiha', 'yuvraj', 'adajane', 'adhiraj', 'ajourni', 'avajane', 'majesti', 'majesty', 'majesty', 'mikolaj', 'mwajuma', 'nikolaj', 'prajwal', 'rajveer', 'semajae', 'tajanae', 'tajveer', 'yajaira', 'ajournee', 'anajulia', 'ellajade', 'emmajane', 'emmajean', 'majestic', 'majestie', 'majestii', 'milajade', 'mirajane', 'elizajane', 'mariajose', 'mariajulia', 'olanrewaju', 'oliviajane', 'abdulmajeed'], 'al': ['ala', 'ali', 'ali', 'alo', 'alo', 'alp', 'aly', 'aly', 'cal', 'dal', 'gal', 'hal', 'kal', 'mal', 'sal', 'tal', 'val', 'val', 'aala', 'adal', 'alaa', 'alaa', 'alai', 'alam', 'alan', 'alba', 'albi', 'alby', 'aldo', 'alea', 'alec', 'alee', 'alek', 'alek', 'alen', 'aleo', 'alex', 'alex', 'alia', 'alie', 'alif', 'alii', 'alik', 'alim', 'alin', 'alis', 'alix', 'alix', 'aliz', 'alla', 'alli', 'ally', 'alma', 'aloe', 'alon', 'aloy', 'alta', 'alva', 'alva', 'alvi', 'alya', 'alyn', 'alys', 'alyx', 'alyx', 'amal', 'amal', 'asal', 'atal', 'azal', 'bali', 'bali', 'cala', 'cale', 'cali', 'cali', 'caly', 'coal', 'dale', 'dali', 'dali', 'daly', 'daly', 'eyal', 'fala', 'fall', 'gala', 'gale', 'gali', 'galo', 'hala', 'hale', 'hali', 'hall', 'halo', 'halo', 'ikal', 'jala', 'kala', 'kale', 'kali', 'kali', 'kalo', 'kalu', 'kaly', 'koal', 'lala', 'lalo', 'mala', 'mali', 'mali', 'malu', 'nala', 'nalo', 'nalu', 'neal', 'nial', 'opal', 'ralo', 'real', 'sala', 'tala', 'tali', 'teal', 'teal', 'vala', 'vale', 'vale', 'vali', 'vali', 'wale', 'wali', 'walt', 'yale', 'yali', 'yali', 'zala', 'zale', 'zeal', 'aalia', 'aalim', 'aalok', 'aaral', 'adali', 'adaly', 'aizal', 'akali', 'akmal', 'alaia', 'alaia', 'alain', 'alaja', 'alana', 'alane', 'alani', 'alani', 'alann', 'alano', 'alany', 'alara', 'alari', 'alaya', 'alban', 'albie', 'albin', 'albus', 'alden', 'alden', 'alder', 'aldin', 'aldon', 'aleah', 'aleck', 'aleem', 'aleen', 'aleha', 'aleia', 'aleix', 'alejo', 'aleki', 'aleks', 'aleli', 'alena', 'alene', 'aleni', 'aleph', 'alera', 'alery', 'alese', 'alesi', 'aleta', 'alexa', 'alexi', 'alexi', 'alexx', 'alexy', 'aleya', 'alfie', 'aliaa', 'aliah', 'alias', 'alice', 'alice', 'alida', 'alieu', 'alifa', 'aliha', 'aliia', 'alija', 'alika', 'alika', 'alila', 'alima', 'alina', 'aline', 'aliou', 'alira', 'alisa', 'alise', 'alita', 'aliya', 'aliza', 'alize', 'allah', 'allan', 'allen', 'alley', 'allia', 'allie', 'allis', 'allyn', 'alman', 'almas', 'almas', 'almir', 'alohi', 'alois', 'alona', 'aloni', 'alora', 'alori', 'alper', 'alpha', 'alpha', 'alson', 'altaf', 'altan', 'altay', 'alteo', 'alter', 'alton', 'aluel', 'alula', 'alula', 'aluna', 'alura', 'alvia', 'alvie', 'alvie', 'alvin', 'alvis', 'alwyn', 'alyah', 'alyan', 'alyas', 'alyce', 'alyea', 'alyla', 'alyna', 'alynn', 'alyra', 'alysa', 'alyse', 'alyss', 'alyus', 'alyza', 'amaal', 'amala', 'amali', 'amaly', 'anala', 'anali', 'analy', 'anfal', 'anzal', 'arale', 'araly', 'arial', 'arsal', 'ayala', 'ayzal', 'balam', 'belal', 'bilal', 'calah', 'calan', 'caleb', 'cal ...

# %%
l = ['noah', 'mark', 'john']

for number1 in l:
    for number2 in l:
        print(f"Number 1: {number1}; number 2: {number2}")
# Out:
# Number 1: noah; number 2: noah
# Number 1: noah; number 2: mark
# Number 1: noah; number 2: john
# Number 1: mark; number 2: noah
# Number 1: mark; number 2: mark
# Number 1: mark; number 2: john
# Number 1: john; number 2: noah
# Number 1: john; number 2: mark
# Number 1: john; number 2: john

# %% [markdown]
# What is the most popular girls' name that is also a boys' name?

# %% [markdown]
# Write a function that takes a prefix as input and prints the number of boys and girls with that prefix (e.g., get_names("m") would list all names that start with "m" and get_names("ma") would only list those that start with "ma").
